# %% [markdown]
# # Installing the SDK
#
# The SDK installer is included as part of the SeisWare installer. We currently support Python 3.7.
#
# When installing the SDK, make sure no "python.exe" processes are running in Task Manager. You can choose to add to the PYTHONPATH when selecting the SDK to install.
#
# ![2-4-2020%203-02-10%20PM.png](attachment:2-4-2020%203-02-10%20PM.png)
#
# Once imported, try running the test application.
#
# Note: If any Python process was running before install, relaunch EVERYTHING.

# %% [markdown]
# # Importing the required modules
#
# To use the SDK we import the entire SeisWare module. We also include sys and some matplotlib libraries for graphing.
#
# The "handle_error" function helps us prevent everything from crashing.

# %%
import sys
import SeisWare
import mpl_toolkits.mplot3d
import matplotlib.pyplot

def handle_error(message, error):
    """
    Helper function to print out the error message to stderr and exit the program.
    """
    print(message, file=sys.stderr)
    print("Error: %s" % (error), file=sys.stderr)
    sys.exit(1)

# %% [markdown]
# Note: If you recieve the error "Can't find the module mpl_toolkits", you need to upgrade matplotlib by typing "pip install --upgrade matplotlib" in the terminal or command prompt.

# %% [markdown]
# ## Connecting to the API Server
#
# In order to connect to a project, we must first connect to a server. This is done through the Connect method of a SeisWare.Connection object.

# %%
connection = SeisWare.Connection()

try:
    serverInfo = SeisWare.Connection.CreateServer()
    connection.Connect(serverInfo.Endpoint(), 5000)
except RuntimeError as err:
    handle_error("Failed to connect to the server", err)

# %% [markdown]
# If the following error appears, you may need to run the cell again. Check Task Manager to make sure "SWAPIServer.exe" is running. "SWAPIService.exe" is NOT the same.
#
# Failed to connect to the server
# Error: APIServer executable could not be located.
#
# # Getting the project list
#
# Once we are connected to a server we can get a list of all the project by calling GetAll on the ProjectManager, which we get through the Connection object. After we have all the projects in our ProjectList, we go through them and find the project that has our passed in name.

# %%
project_list = SeisWare.ProjectList()

try:
    connection.ProjectManager().GetAll(project_list)
except RuntimeError as err:
    handle_error("Failed to get the project list from the server", err)

# %% [markdown]
# We can see a list of our projects by iterating through the project_list

# %%
for project in project_list:
    print(project.Name())
# Out:
# Tableland_9.2_Demo
# Intro to Petrophysics
# Cooper_2D
# AB Wells Imperial
# Cooper_2D
# Tableland_9.2_Demo
# FDS Applachian - Copy
# Celtic
# Celtic
# Celtic
# Celtic-Clean
# Production Testing Remote
# Intro to Petrophysics
# SeisWare Trial Data Set

# %%
# Get the project we want to connect to
project_name = "SeisWare Trial Data Set"

projects = [project for project in project_list if project.Name() == project_name]
if not projects:
    print("No project was found", file=sys.stderr)
    sys.exit(1)

# %%
projects
# Out:
# [<SeisWare.seisware_sdk_311.Project; proxy of <Swig Object of type 'SeisWare::Project *' at 0x00000185EA34E5E0> >]

# %% [markdown]
# # Connecting to the project
#
# We then have to connect to that project by creating a SeisWare.LoginInstance object and calling Open on it with our connection and project.

# %%
login_instance = SeisWare.LoginInstance()
try:
    login_instance.Open(connection, projects[0])
except RuntimeError as err:
    handle_error("Failed to connect to the project", err)
# Out:
# Failed to connect to the project
# Error: The requested operation failed: Project upgrade required.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# c:\Users\apadilla\Anaconda3\envs\py3115\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
login_instance
# Out:
# <SeisWare.LoginInstance; proxy of <Swig Object of type 'SeisWare::LoginInstance *' at 0x000001F25C5FFF60> >

# %% [markdown]
# # Getting the wells in the project
#
# We first get all the wells from the project by calling GetAll on the WellManager, which we get through our
# LoginInstance object.
#
#
#
# We then go through all the wells, looking for the well with our passed in UWI and return it.

# %%
# Get the wells from the project
well_list = SeisWare.WellList()
try:
    login_instance.WellManager().GetAll(well_list)
except RuntimeError as err:
    handle_error("Failed to get all the wells from the project", err)

# %% [markdown]
# We then print out how many wells our project has along with the names of 5 of the
# wells.

# %%
print("Number of wells in project: %i" % (len(well_list)))
print("Names of wells: %s" % (", ".join([well.Name() for well in well_list[:7]])))
# Out:
# Number of wells in project: 7
# Names of wells: Well 4, Well 6, Well 1, Well 2, Well 3, Well 7, Well 5

# %% [markdown]
# We then go through all the wells, looking for the well with our passed in UWI and return it.

# %%
well_uwi = "Well 1"


# Get the well we want
wells = [well for well in well_list if well.UWI() == well_uwi]
if not wells:
    print("No well was found", file=sys.stderr)
    sys.exit(1)

# Return the well of the passed in UWI

well = wells[0]

# %%
help(well)
# Out:
# Help on Well in module SeisWare object:
#
# class Well(builtins.object)
#  |  Well(*args)
#  |
#  |  Methods defined here:
#  |
#  |  BottomHole(self, *args)
#  |
#  |  BottomLoc(self, *args)
#  |
#  |  County(self, *args)
#  |
#  |  DatumElevation(self, *args)
#  |
#  |  DepthDatumUnit(self, *args)
#  |
#  |  Description(self, *args)
#  |
#  |  Field(self, *args)
#  |
#  |  GovernmentID(self, *args)
#  |
#  |  GroundElevation(self, *args)
#  |
#  |  ID(self, *args)
#  |
#  |  KB(self, *args)
#  |
#  |  LeaseName(self, *args)
#  |
#  |  LeaseOperator(self, *args)
#  |
#  |  Name(self, *args)
#  |
#  |  Number(self, *args)
#  |
#  |  OwnerID(self)
#  |
#  |  PlatformID(self, *args)
#  |
#  |  RigRelDate(self, *args)
#  |
#  |  SpudDate(self, *args)
#  |
#  |  State(self, *args)
#  |
#  |  StatusDate(self, *args)
#  |
#  |  SurfaceLoc(self, *args)
#  |
#  |  Symbol(self, *args)
#  |
#  |  TopHole(self, *args)
#  |
#  |  TotalDepth(self, *args)
#  |
#  |  UWI(self, *args)
#  |
#  |  VerticalDepth(self, *args)
#  |
#  |  WaterDepth(self, *args)
#  |
#  |  WellStatus(self, *args)
#  |
#  |  __init__(self, *args)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__ = _swig_repr(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __swig_destroy__ = delete_Well(...)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  thisown
#  |      The membership flag
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  InvalidWellSymbolCode = -1

# %%
well.ID()
# Out:
# <SeisWare.ID; proxy of <Swig Object of type 'SeisWare::UserKey *' at 0x000001F25C4C9750> >

# %%
well.Name()
# Out:
# 'Well 1'

# %%
well.UWI()
# Out:
# 'Well 1'

# %% [markdown]
# We first create a new well top, along with all required information.
#
# The ParentID is used to set the associated well UWI. This is pulled from the Well Object created earlier by iterating through the list.
#
# The name of the formation is set as "Formation for L&L"
#
# The type of this new well top is MD as set by TopType, and has a depth of 1000m. The depth value must be set using a SeisWare.Measurement object with a float and a SeisWare.Unit object passed in.

# %%
# Create a new well top
new_well_top = SeisWare.WellTop()

new_well_top.ParentID(well.ID())
new_well_top.Formation("Formation for L&L")
new_well_top.TopType(SeisWare.WellTopType_TVD)
new_well_top.Depth(SeisWare.Measurement(1000.0, SeisWare.Unit.Meter))

# %% [markdown]
# We add well tops to the project by calling Add on the WellTopManager, which we get through our LoginInstance
# object.

# %%
# Add the new well top to the project
try:
    login_instance.WellTopManager().Add(new_well_top)
except RuntimeError as err:
    handle_error("Failed to add the well top of well %s to the project" % (well.UWI()), err)

# %% [markdown]
# We then modify our well top depth by adding 500m to it. The depth is a SeisWare.Measurement object and in order to do math on a Measurement object we use other Measurement objects.

# %%
# Update the new well top's depth to be it's current depth plus 500 meters
new_well_top.Depth(new_well_top.Depth() + SeisWare.Measurement(500.0, SeisWare.Unit.Meter))

# %% [markdown]
# The well top is then updated by calling Update on the WellTopManager.

# %%
# Save the updated well top back to the project
try:
    login_instance.WellTopManager().Update(new_well_top)
except RuntimeError as err:
    handle_error("Failed to update a well top of well %s" % (well.UWI()), err)

# %% [markdown]
# Finally to remove a well top from our project, you call Remove on the WellTopManager and pass it the well top you want to delete.

# %%
# Delete the newly added well top from the project
try:
    login_instance.WellTopManager().Remove(new_well_top)
except RuntimeError as err:
    handle_error("Failed to remove the well top of well %s" % (well.UWI()), err)

# %% [markdown]
# # Get well tops from project
#
# We first get all the well tops from the project for a specific well by calling GetAllForWell on the
# WellTopManager, which we get through our LoginInstance object.

# %%
# Get the well tops for a well from the project
well_top_list = SeisWare.WellTopList()
try:
    login_instance.WellTopManager().GetAllForWell(well.ID(), well_top_list)
except RuntimeError as err:
    handle_error("Failed to get the well tops of well %s from the project" % (well.UWI()), err)

# %% [markdown]
# We then go through the WellTopList, looking for well tops that have our passed in formation names.

# %%
for top in well_top_list:
    print(top.Formation())
    print(top.MD().Value(SeisWare.Unit.Meter))
# Out:
# Top 2
# 1181.4048
# Top 3
# 1639.775232
# Top 1
# 1339.291201472

# %%
top_well_top = "Top 1"
base_well_top = "Top 2"

# Get the well tops we want
well_tops = [well_top for well_top in well_top_list if well_top.Formation() in (top_well_top, base_well_top)]
if len(well_tops) != 2:
    print("No well tops were found", file=sys.stderr)
    sys.exit(1)

# %% [markdown]
# After we find them, we sort them to ensure the more shallow one is first in the list.

# %%
# Make the first well top in the list be the more shallow one
if well_tops[0].MD() > well_tops[1].MD():
    well_tops[0], well_tops[1] = well_tops[1], well_tops[0]

# %% [markdown]
# Then we print out the MD of the tops. The MD is stored as a SeisWare.Measurement object and in order to get a number out, you must call Value and pass in the units you want the value back in.

# %%
# Print the well top depths
first_well_top_depth = well_tops[0].MD().Value(SeisWare.Unit.Meter)
second_well_top_depth = well_tops[1].MD().Value(SeisWare.Unit.Meter)
print("Depth of well top %s of well %s: %.4fm" % (well_tops[0].Formation(), well.UWI(), first_well_top_depth))
print("Depth of well top %s of well %s: %.4fm" % (well_tops[1].Formation(), well.UWI(), second_well_top_depth))
print()
# Out:
# Depth of well top Top 2 of well Well 1: 1181.4048m
# Depth of well top Top 1 of well Well 1: 1339.2912m

# %% [markdown]
# Finally we return the two tops we got for our passed in formation names.

# %%
top_well_top = well_tops[0]
base_well_top = well_tops[1]

# %% [markdown]
# # Get a log curve from the project
#
# We first get all the log curves from the project for a specific well by calling GetAllForWell on the
# LogCurveManager, which we get through our LoginInstance object.

# %%
# Get the log curves for a well from the project
log_curve_list = SeisWare.LogCurveList()
try:
    login_instance.LogCurveManager().GetAllForWell(well.ID(), log_curve_list)
except RuntimeError as err:
    handle_error("Failed to get the log curves of well %s from the project" % (well.UWI()), err)

for log_curve in log_curve_list:
    print(log_curve.Name())
# Out:
# inverted sonic
# DT
# GR

# %% [markdown]
# We then go through the LogCurveList, looking for log curve that has our passed in name.

# %%
log_curve_name = "DT"
# Get the log curve we want
log_curves = [log_curve for log_curve in log_curve_list if log_curve.Name() == log_curve_name]
if not log_curves:
    print("No log curve was found", file=sys.stderr)
    sys.exit(1)

# %% [markdown]
# Then we print out the log curves top and base depths, which are SeisWare.Measurement objects. We have to call Value and pass in the units we want the value back in.

# %%
 # Print the top and base depths of the log curve
log_curve_top_depth = log_curves[0].TopDepth().Value(SeisWare.Unit.Meter)
log_curve_base_depth = log_curves[0].BaseDepth().Value(SeisWare.Unit.Meter)
print("Depths for log curve %s of well %s" % (log_curve_name, well.UWI()))
print("Top depth: %.4fm" % (log_curve_top_depth))
print("Base depth: %.4fm" % (log_curve_base_depth))
print()
# Out:
# Depths for log curve DT of well Well 1
# Top depth: 1308.0492m
# Base depth: 1758.0864m

# %%
log_curves[0]
# Out:
# <SeisWare.LogCurve; proxy of <Swig Object of type 'SeisWare::LogCurve *' at 0x000001F25C0C48A0> >

# %% [markdown]
# Next we call PopulateValues on our log curve, which will populate all the values of the log curve, which we can access by calling Values on our LogCurve object. The reason you have to call PopulateValues instead of just getting the values when you call GetAll is because the values are stored in a file and could take longer to get. It is also important to note that if you try to get the objects values before you call PopulateValues, it will throw.

# %%
# Populate the log curve with it's values
try:
    login_instance.LogCurveManager().PopulateValues(log_curves[0])
except RuntimeError as err:
    handle_error("Failed to populate the values of log curve %s of well %s from the project" % (log_curve_name, well.UWI()), err)

# %%
log_curve = [log_curves[0]]

# %%
for i in log_curve:
    print(i)
# Out:
# <SeisWare.LogCurve; proxy of <Swig Object of type 'SeisWare::LogCurve *' at 0x000001F25C0C48A0> >

# %% [markdown]
# Print log curve details
#
# We first get the values out of the log curve by creating a SeisWare.DoublesList and calling Values on the LogCurve object with the DoublesList.

# %%
log_curve_values = SeisWare.DoublesList()
log_curve[0].Values(log_curve_values)

# %%
log_curve
# Out:
# [<SeisWare.LogCurve; proxy of <Swig Object of type 'SeisWare::LogCurve *' at 0x000001F25C0C48A0> >]

# %%
log_curve_values
# Out:
# <SeisWare.DoublesList; proxy of <Swig Object of type 'std::vector< double > *' at 0x000001F25C298AE0> >

# %%
for i in log_curve_values:
    print(i)
# Out:
# 49.1608
# 49.1608
# 49.1608
# 49.1608
# 49.1608
# 49.1608
# 49.7177
# 49.8404
# 49.7283
# 50.2406
# 49.267
# 49.8038
# 49.6903
# 49.8294
# 49.4992
# 49.9062
# 51.685
# 74.08
# 65.32
# 54.2464
# 49.7104
# 54.2108
# 46.7648
# 56.5565
# 64.3171
# 73.1458
# 71.0932
# 78.3677
# 78.6275
# 85.9786
# 79.2633
# 94.3201
# 73.3059
# 75.9029
# 66.0084
# 65.172
# 60.571
# 65.7498
# 45.9995
# 42.3779
# 40.5624
# 53.9001
# 48.1702
# 48.8767
# 50.089
# 48.8798
# 53.1208
# 54.0658
# 54.4423
# 54.3832
# 54.1706
# 54.1828
# 54.0161
# 53.9308
# 54.4956
# 59.7077
# 77.4708
# 68.7793
# 78.1536
# 84.1274
# 65.825
# 67.2493
# 72.8826
# 89.0114
# 71.2096
# 77.5366
# 86.5644
# 82.7833
# 84.3086
# 84.2285
# 123.0061
# 123.7224
# 121.5009
# 82.4937
# 77.5084
# 74.2266
# 73.7403
# 76.3994
# 78.068
# 78.5061
# 78.6204
# 78.8553
# 78.2727
# 79.9968
# 81.8954
# 83.3774
# 85.2529
# 85.7265
# 85.5816
# 85.9929
# 86.385
# 86.6778
# 86.6842
# 85.9356
# 84.9457
# 84.0736
# 84.1292
# 84.7362
# 85.2115
# 85.4533
# 85.4087
# 85.4439
# 86.1882
# 87.1713
# 87.6583
# 89.4733
# 89.8986
# 89.4855
# 89.5312
# 87.9917
# 87.5323
# 87.6113
# 87.4019
# 87.3979
# 86.8484
# 86.5354
# 86.2219
# 86.0067
# 86.3626
# 86.3652
# 86.0688
# 84.9296
# 84.37
# 83.6748
# 83.9965
# 85.0799
# 85.0531
# 84.7643
# 84.4319
# 84.2331
# 84.6224
# 85.457
# 85.7087
# 85.2322
# 84.6136
# 84.2779
# 83.6396
# 83.7097
# 83.825
# 83.5551
# 83.5898
# 83.9387
# 83.8494
# 83.8537
# 84.0499
# 84.2766
# 84.8006
# 84.6392
# 84.6789
# 84.4764
# 83.4279
# 82.3912
# 81.6178
# 80.6514
# 79.2688
# 77.8473
# 76.3837
# 73.6765
# 72.3582
# 72.3926
# 75.8792
# 75.69
# 75.6867
# 75.3445
# 72.0058
# 67.2494
# 64.6818
# 64.5408
# 64.5202
# 64.1198
# 64.4147
# 63.5451
# 63.5337
# 62.6374
# 60.9937
# 59.3721
# 58.2613
# 58.3685
# 58.1766
# 58.0076
# 58.2787
# 57.8533
# 59.1289
# 61.02
# 61.4086
# 62.003
# 62.2045
# 62.2035
# 62.4952
# 62.7368
# 61.9322
# 61.4519
# 60.8028
# 60.8522
# 62.1698
# 62.4757
# 62.9778
# 63.2482
# 63.4312
# 63.9135
# 57.7541
# 66.9447
# 68.218
# 69.7161
# 69.3861
# 69.4543
# 71.4952
# 72.944
# 75.4275
# 75.8304
# 75.5545
# 75.8083
# 76.2888
# 77.0785
# 76.8109
# 75.3222
# 74.3715
# 74.0933
# 75.5692
# 76.1382
# 77.292
# 78.0922
# 77.5816
# 78.8998
# 78.1327
# 77.8109
# 74.8184
# 72.5157
# 70.4336
# 68.2706
# 68.0434
# 68.1252
# 68.243
# 68.5847
# 68.8224
# 69.7297
# 71.7778
# 74.8797
# 77.8518
# 79.2095
# 79.3682
# 78.6767
# 78.0465
# 77.3776
# 76.7227
# 76.493
# 77.0532
# 78.5733
# 79.0008
# 79.3949
# 78.6872
# 77.7748
# 78.5633
# 79.0219
# 80.2483
# 80.2256
# 77.2823
# 75.765
# 74.1622
# 73.4438
# 76.4437
# 78.0715
# 79.174
# 79.8603
# 79.6598
# 79.2399
# 79.2633
# 79.7472
# 79.6076
# 79.0473
# 78.8642
# 78.9063
# 79.5977
# 80.2328
# 80.39
# 80.7731
# 79.9459
# 78.0995
# 77.5856
# 77.6295
# 78.3822
# 79.06
# 79.3315
# 79.4628
# 79.7599
# 79.5182
# 78.5288
# 78.0623
# 77.4227
# 76.7511
# 76.4235
# 76.1082
# 75.5942
# 75.8034
# 76.2627
# 77.1835
# 77.7751
# 78.3627
# 79.5288
# 80.3826
# 81.6027
# 82.7612
# 82.3931
# 80.9669
# 79.6477
# 78.0419
# 75.9787
# 75.4839
# 75.5923
# 75.9699
# 77.0436
# 76.9208
# 76.747
# 76.2551
# 75.8447
# 76.1989
# 76.3798
# 77.1416
# 78.4576
# 79.847
# 80.9068
# 81.6276
# 81.8585
# 81.9805
# 82.2277
# 81.8512
# 80.0955
# 77.8432
# 77.9378
# 78.197
# 82.4638
# 86.0295
# 85.8776
# 85.8251
# 85.7415
# 84.6516
# 84.78
# 84.2505
# 83.8532
# 83.8453
# 83.789
# 83.9173
# 83.6446
# 82.7754
# 81.8744
# 81.6914
# 80.701
# 81.1588
# 81.6554
# 80.3551
# 79.2466
# 77.5639
# 75.3158
# 75.392
# 76.1558
# 79.8702
# 80.5347
# 80.6487
# 80.3269
# 80.0021
# 79.6024
# 79.6802
# 80.4286
# 80.7324
# 80.7588
# 80.7396
# 78.0381
# 75.5339
# 72.9087
# 70.9392
# 70.2745
# 65.0028
# 58.5909
# 55.8874
# 53.1682
# 53.0986
# 52.9137
# 52.2459
# 50.8486
# 50.4398
# 50.4924
# 51.2016
# 51.8729
# 52.8275
# 53.5572
# 54.0268
# 54.1957
# 53.9624
# 54.0468
# 54.2766
# 54.6644
# 54.8972
# 54.3748
# 53.2254
# 51.9424
# 51.3822
# 50.7062
# 50.835
# 50.5061
# 50.3046
# 50.8491
# 50.4424
# 50.6923
# 50.9131
# 50.0385
# 50.7042
# 50.061
# 49.7246
# 50.4016
# 50.202
# 49.8252
# 50.3093
# 50.3179
# 49.9809
# 50.0138
# 50.6706
# 56.173
# 61.3321
# 60.6191
# 61.9177
# 64.2738
# 65.6066
# 66.8068
# 67.5538
# 67.8941
# 68.3554
# 67.4931
# 67.426
# 67.7592
# 66.9822
# 66.7043
# 66.3159
# 65.113
# 65.0676
# 64.1059
# 63.5332
# 64.6366
# 67.3075
# 70.9698
# 73.9406
# 74.0192
# 72.6229
# 70.093
# 66.9171
# 65.3114
# 67.4455
# 70.5383
# 71.6276
# 73.7476
# 67.8509
# 64.4676
# 64.3814
# 64.1182
# 64.0292
# 63.972
# 63.9262
# 63.8372
# 63.8446
# 63.4867
# 63.0859
# 62.8846
# 62.4213
# 62.1248
# 61.7911
# 62.2847
# 61.7435
# 62.2426
# 62.1614
# 62.3794
# 62.5621
# 62.5625
# 64.9355
# 67.399
# 67.4171
# 68.5421
# 72.2054
# 77.1138
# 77.5474
# 75.5514
# 71.8923
# 68.5623
# 66.1871
# 64.1923
# 63.3678
# 62.2639
# 61.7006
# 62.3546
# 63.0206
# 63.6136
# 63.8538
# 63.196
# 62.6093
# 62.0807
# 61.8855
# 61.4387
# 61.1348
# 61.34
# 61.7009
# 63.0222
# 64.1056
# 64.9471
# 64.5801
# 64.5427
# 63.736
# 64.1466
# 65.9522
# 64.2667
# 67.5582
# 67.3596
# 65.1484
# 69.8376
# 64.247
# 63.66
# 63.9682
# 64.1929
# 67.2452
# 70.7157
# 73.8341
# 73.9718
# 71.1815
# 69.5857
# 67.2066
# 60.5297
# 59.498
# 60.4197
# 61.9093
# 63.7902
# 65.6582
# 66.9483
# 69.7781
# 71.8909
# 73.0124
# 70.951
# 68.5546
# 65.3854
# 65.0264
# 64.9721
# 65.2745
# 65.8308
# 65.9566
# 67.5388
# 67.5111
# 66.8638
# 67.1217
# 66.4413
# 65.6799
# 65.8742
# 67.3126
# 65.9487
# 66.1508
# 66.3149
# 66.6177
# 66.0412
# 63.7697
# 64.015
# 66.3293
# 68.1986
# 69.8714
# 68.7164
# 68.2963
# 67.5238
# 66.3097
# 65.3379
# 65.1206
# 64.7731
# 64.6307
# 64.7854
# 65.4975
# 65.5585
# 66.1783
# 66.9615
# 66.5783
# 65.9859
# 64.7625
# 64.4146
# 64.0404
# 63.873
# 64.0578
# 64.8756
# 65.7845
# 66.9552
# 67.2589
# 65.9428
# 64.4068
# 64.0591
# 63.549
# 63.2057
# 62.9055
# 62.3117
# 64.3422
# 69.1481
# 71.9688
# 76.1351
# 78.5025
# 77.83
# 76.3673
# 75.1253
# 74.5867
# 74.9623
# 74.5511
# 74.9618
# 75.6283
# 75.4214
# 76.2448
# 77.2429
# 76.6041
# 76.5015
# 76.8869
# 77.4634
# 78.1307
# 76.4361
# 72.4837
# 68.0597
# 64.4345
# 65.3834
# 65.976
# 67.0964
# 68.1253
# 68.5501
# 67.875
# 66.7786
# 65.8922
# 64.4314
# 62.406
# 62.0801
# 63.0579
# 62.5628
# 62.8475
# 62.6316
# 64.1514
# 62.201
# 62.4273
# 62.0868
# 62.3679
# 65.2488
# 68.9343
# 70.3908
# 70.7885
# 70.9134
# 70.7938
# 72.9166
# 76.7408
# 78.1083
# 74.6401
# 70.283
# 66.0558
# 62.4992
# 62.4204
# 62.8487
# 63.7713
# 64.6545
# 65.2911
# 65.4848
# 65.5317
# 65.6992
# 65.5906
# 65.3096
# 65.219
# 65.0872
# 64.6389
# 64.3983
# 63.7852
# 62.2521
# 62.0161
# 62.5691
# 62.4542
# 63.1123
# 64.9867
# 63.8738
# 63.7639
# 63.6074
# 64.0362
# 65.7981
# 65.5875
# 65.8078
# 68.1646
# 70.9301
# 72.1498
# 70.9502
# 67.9543
# 64.9178
# 63.5036
# 63.1906
# 63.269
# 62.6384
# 62.3392
# 61.668
# 61.941
# 62.0053
# 61.8198
# 61.7401
# 61.469
# 61.437
# 61.4193
# 61.8728
# 62.194
# 63.5471
# 65.9744
# 67.4783
# 70.4163
# 73.5069
# 76.1915
# 76.1176
# 74.0757
# 69.6986
# 65.7934
# 63.5586
# 62.6594
# 61.4806
# 61.7161
# 61.9506
# 61.8369
# 62.0013
# 62.7823
# 63.8842
# 67.1969
# 71.2361
# 72.278
# 73.3129
# 73.5447
# 74.0588
# 74.8015
# 72.5522
# 68.7399
# 64.2761
# 61.4844
# 61.3706
# 61.1623
# 61.4228
# 61.3914
# 61.7192
# 62.1425
# 62.289
# 62.6065
# 62.3495
# 61.9299
# 62.0984
# 62.5005
# 62.7894
# 63.4109
# 63.4454
# 63.8443
# 64.3433
# 64.0629
# 64.141
# 64.2937
# 64.506
# 64.6691
# 64.8534
# 65.3397
# 65.3132
# 65.5598
# 65.4317
# 65.2146
# 64.5484
# 64.3747
# 63.8142
# 63.4331
# 63.2016
# 63.2215
# 64.1418
# 64.2502
# 64.6179
# 64.0132
# 62.3491
# 62.993
# 63.5044
# 64.4887
# 64.8719
# 65.3112
# 65.1752
# 64.511
# 64.592
# 64.2051
# 64.1883
# 64.9528
# 65.798
# 65.9601
# 65.7324
# 64.8645
# 64.6069
# 63.7756
# 62.3689
# 61.9425
# 59.9397
# 58.838
# 59.1567
# 59.8273
# 63.4831
# 63.3299
# 63.3981
# 63.9085
# 63.4099
# 64.8972
# 66.1925
# 64.6009
# 65.8819
# 66.8128
# 80.3736
# 89.5758
# 84.974
# 86.0693
# 58.2607
# 49.2613
# 64.1789
# 61.5464
# 26.5623
# 60.8584
# 61.1665
# 62.5053
# 64.0804
# 65.5925
# 64.5371
# 65.7656
# 66.1244
# 64.2636
# 64.4682
# 63.4993
# 62.7362
# 63.8691
# 61.8228
# 63.1822
# 64.9649
# 66.5172
# 67.4536
# 66.668
# 64.5681
# 63.625
# 63.0089
# 61.6602
# 60.557
# 59.8922
# 59.7967
# 60.2172
# 60.3411
# 60.8598
# 60.4837
# 61.2673
# 61.0663
# 61.4965
# 61.8979
# 64.4218
# 66.792
# 68.8031
# 70.6064
# 71.1843
# 68.1072
# 65.8015
# 65.2352
# 64.1814
# 63.5716
# 61.7893
# 61.2591
# 59.6027
# 59.7664
# 61.9393
# 62.772
# 63.8347
# 66.8111
# 67.3954
# 69.1562
# 69.5402
# 69.7974
# 68.8191
# 68.706
# 68.4772
# 68.3057
# 68.0207
# 69.1672
# 69.3751
# 69.8626
# 69.8106
# 69.2723
# 66.7187
# 65.7452
# 66.1163
# 68.2058
# 68.9158
# 69.9051
# 72.6585
# 72.3087
# 72.2596
# 71.4363
# 70.0092
# 68.2445
# 67.7601
# 68.3087
# 68.9362
# 70.4078
# 71.5429
# 71.0171
# 69.0025
# 67.1315
# 64.3068
# 63.2331
# 62.769
# 62.2628
# 62.4323
# 63.2027
# 64.5264
# 66.3404
# 68.284
# 68.1217
# 67.1616
# 66.3602
# 64.9253
# 65.8557
# 65.9774
# 65.3453
# 65.049
# 63.5736
# 61.3656
# 61.1502
# 61.7377
# 62.8198
# 63.6996
# 65.0743
# 65.8515
# 67.1533
# 68.4894
# 68.7259
# 68.0955
# 66.2444
# 63.3588
# 61.8934
# 62.6632
# 64.7487
# 68.7861
# 72.5182
# 73.7023
# 74.3829
# 74.5141
# 74.7493
# 75.3623
# 76.4087
# 77.0382
# 76.3321
# 75.7524
# 72.8039
# 68.5531
# 65.8014
# 62.8035
# 61.1681
# 60.1561
# 59.817
# 50.7624
# 60.8175
# 59.4709
# 68.144
# 58.9861
# 58.9033
# 59.1933
# 59.5472
# 61.7537
# 64.6017
# 65.1618
# 62.9392
# 60.6846
# 59.9909
# 60.9206
# 61.943
# 63.3311
# 64.7327
# 66.1764
# 66.9795
# 66.75
# 64.6692
# 64.4689
# 64.9897
# 65.4534
# 65.5371
# 64.317
# 62.5136
# 61.5424
# 61.118
# 62.2799
# 62.1681
# 61.9305
# 61.6731
# 61.4787
# 62.3398
# 63.2982
# 63.0527
# 63.1962
# 62.8485
# 61.8817
# 61.2458
# 61.2311
# 61.7825
# 61.2455
# 60.5324
# 60.542
# 60.5347
# 59.9042
# 59.3179
# 58.8662
# 58.6262
# 58.8089
# 59.7409
# 61.5862
# 63.6352
# 64.1817
# 64.2927
# 64.8716
# 66.2748
# 69.0643
# 70.7948
# 71.3367
# 69.7069
# 66.9196
# 64.1313
# 62.6493
# 63.024
# 63.0607
# 63.403
# 63.7539
# 64.7576
# 65.791
# 67.2184
# 65.9934
# 65.5698
# 63.5562
# 61.8023
# 61.002
# 59.1449
# 58.9123
# 60.007
# 60.641
# 60.8203
# 61.1147
# 60.9387
# 61.0159
# 62.8918
# 65.2112
# 66.1452
# 67.9548
# 69.0034
# 68.6857
# 66.9834
# 65.3414
# 63.0462
# 62.7784
# 62.5015
# 61.6544
# 61.9737
# 62.4536
# 62.7804
# 62.8941
# 62.044
# 62.2163
# 62.2475
# 61.2649
# 61.0566
# 60.8788
# 61.785
# 63.0788
# 63.2846
# 63.1073
# 62.8306
# 64.9903
# 68.552
# 68.6543
# 69.5184
# 68.1619
# 66.8791
# 65.4481
# 64.4834
# 64.2741
# 62.8168
# 62.759
# 62.6101
# 62.0523
# 62.693
# 63.2414
# 63.4407
# 63.5764
# 62.5423
# 61.9757
# 60.9594
# 60.5807
# 60.6004
# 61.3221
# 61.7908
# 62.3579
# 61.8657
# 61.2766
# 61.4695
# 63.5919
# 65.1996
# 67.2588
# 67.7611
# 68.4783
# 69.8431
# 69.4347
# 67.7906
# 66.5325
# 65.5845
# 65.8485
# 65.6491
# 65.7601
# 65.376
# 65.8123
# 66.9708
# 68.1628
# 68.6041
# 68.6607
# 67.5247
# 67.6228
# 67.6645
# 67.4237
# 68.692
# 69.9866
# 71.0272
# 70.8696
# 69.4345
# 67.6477
# 67.3783
# 68.4405
# 69.2281
# 68.5653
# 66.2993
# 63.8837
# 64.831
# 66.8442
# 66.597
# 66.8132
# 64.3647
# 63.4671
# 62.9786
# 62.9218
# 62.7148
# 61.9771
# 61.5304
# 60.7834
# 60.0345
# 60.4046
# 61.1033
# 61.3615
# 61.1354
# 61.2401
# 61.9014
# 62.1787
# 62.5923
# 62.5046
# 61.7342
# 61.8267
# 61.3832
# 60.7674
# 59.8922
# 59.971
# 58.0217
# 57.1854
# 58.5017
# 59.2959
# 62.7736
# 63.6287
# 64.8204
# 65.8286
# 67.4624
# 68.1306
# 70.7368
# 68.8912
# 68.1725
# 64.3137
# 63.684
# 63.9966
# 65.7251
# 66.5872
# 66.8302
# 69.1012
# 68.6186
# 68.1592
# 65.4395
# 60.6434
# 60.5049
# 59.8529
# 59.3917
# 60.3073
# 60.3237
# 60.7365
# 61.2129
# 60.5897
# 62.3037
# 64.4492
# 63.076
# 62.7178
# 62.3333
# 61.7725
# 61.7864
# 62.2244
# 62.0335
# 60.6824
# 59.8282
# 59.4197
# 60.1043
# 59.1303
# 58.66
# 58.1595
# 59.2354
# 58.4122
# 59.8018
# 61.0006
# 62.6317
# 63.1813
# 64.0551
# 63.7406
# 64.256
# 66.0684
# 66.1144
# 66.3982
# 68.5227
# 68.4238
# 69.9838
# 69.6383
# 68.7071
# 65.4436
# 62.2905
# 60.8942
# 60.6418
# 62.1489
# 64.1514
# 65.7857
# 64.5807
# 64.1028
# 63.1307
# 63.0206
# 64.1236
# 64.3421
# 63.5628
# 63.9715
# 64.011
# 63.7523
# 63.8265
# 63.8506
# 62.0923
# 62.9063
# 64.0413
# 64.8392
# 66.4121
# 66.3993
# 67.682
# 68.1197
# 67.568
# 66.9174
# 63.9823
# 61.6637
# 60.4795
# 61.1693
# 60.171
# 59.8491
# 59.943
# 59.409
# 59.5381
# 59.85
# 60.7656
# 59.7501
# 60.7905
# 62.8532
# 64.3236
# 66.3682
# 68.44
# 69.089
# 69.098
# 61.4511
# 66.6398
# 65.4443
# 63.8905
# 62.708
# 61.2543
# 59.6817
# 59.3276
# 59.0939
# 60.1367
# 61.0645
# 62.4939
# 64.0601
# 63.653
# 64.9689
# 65.7408
# 67.9458
# 69.1365
# 68.6313
# 69.0299
# 66.9254
# 64.8642
# 62.7896
# 61.5957
# 60.701
# 60.4153
# 60.4112
# 59.2614
# 59.5533
# 59.7958
# 59.8385
# 59.4879
# 58.0016
# 56.6309
# 57.3228
# 56.5695
# 57.0398
# 58.2784
# 59.0844
# 59.5549
# 60.567
# 62.5515
# 65.1126
# 67.7691
# 69.9001
# 70.405
# 70.3812
# 69.9158
# 68.328
# 66.1259
# 65.6261
# 65.4162
# 65.5294
# 65.7076
# 65.0162
# 65.7752
# 67.0916
# 68.6029
# 69.9038
# 70.0945
# 69.3758
# 68.814
# 69.131
# 68.6423
# 68.2098
# 67.6336
# 66.6346
# 65.7024
# 65.5477
# 65.2234
# 65.8127
# 65.9541
# 65.8596
# 66.1124
# 66.548
# 67.6989
# 68.1792
# 68.5897
# 68.377
# 66.515
# 65.9878
# 64.7609
# 64.178
# 65.2066
# 65.4436
# 66.4883
# 66.4638
# 65.9469
# 66.9007
# 65.1237
# 64.6209
# 64.4075
# 63.0375
# 63.0135
# 60.9948
# 61.6093
# 60.352
# 60.3576
# 41.1654
# 61.0297
# 59.3844
# 60.7249
# 61.4001
# 59.9435
# 61.9629
# 60.7634
# 59.9914
# 59.9535
# 60.8247
# 62.5636
# 62.2596
# 62.4524
# 62.8304
# 63.4861
# 64.0184
# 65.6754
# 67.5893
# 67.9937
# 66.9446
# 66.1905
# 63.992
# 62.2597
# 60.3013
# 59.7118
# 60.4705
# 50.7506
# 59.4159
# 58.249
# 57.3093
# 57.7638
# 57.5766
# 58.8076
# 59.573
# 59.7076
# 60.3987
# 63.7182
# 65.9306
# 66.5174
# 68.5485
# 69.2731
# 70.4876
# 69.3526
# 67.1017
# 65.8016
# 64.2488
# 63.6312
# 62.6497
# 63.4615
# 63.3406
# 61.7419
# 62.0466
# 63.7094
# 63.7732
# 64.0164
# 66.1792
# 65.5088
# 64.4826
# 65.1102
# 55.4246
# 55.7526
# 65.4727
# 64.0464
# 64.3229
# 65.7476
# 65.9578
# 67.9237
# 68.8062
# 67.9093
# 66.0734
# 65.3809
# 63.8278
# 62.3589
# 62.6378
# 90.4091
# 89.4341
# 41.8937
# 41.6035
# 59.9071
# 59.3703
# 58.4593
# 58.0264
# 59.9371
# 58.9144
# 60.5158
# 60.6324
# 64.7097
# 66.1839
# 69.0175
# 67.4005
# 67.8145
# 66.3735
# 65.5467
# 64.0672
# 62.8876
# 61.3651
# 60.2891
# 59.1908
# 59.3055
# 60.1952
# 60.8834
# 59.3858
# 57.7704
# 56.2685
# 56.3091
# 58.3241
# 59.7188
# 61.2515
# 65.6761
# 67.5975
# 68.526
# 69.208
# 65.2786
# 63.7211
# 62.4767
# 63.7222
# 63.5663
# 65.7933
# 62.5236
# 64.3069
# 64.2882
# 79.9267
# 82.7923
# 73.0007
# 72.3745
# 56.9723
# 57.7023
# 64.2481
# 65.3602
# 64.3086
# 63.8992
# 62.8465
# 63.1162
# 63.6316
# 64.5644
# 66.3799
# 66.6966
# 66.6666
# 66.8928
# 57.6383
# 64.9393
# 63.2841
# 63.5113
# 62.3162
# 62.1689
# 63.1985
# 63.3517
# 62.8803
# 63.8818
# 62.8738
# 62.1633
# 63.1733
# 64.0677
# 63.4348
# 64.0876
# 64.5981
# 64.4549
# 57.6153
# 64.6188
# 58.3604
# 64.1719
# 64.6931
# 64.6236
# 66.2904
# 67.1531
# 68.3996
# 64.8203
# 63.2808
# 63.0141
# 63.7953
# 62.7813
# 63.8673
# 64.57
# 63.4928
# 62.8676
# 62.9259
# 62.7163
# 64.2859
# 64.2801
# 65.2757
# 64.4748
# 64.8028
# 64.8078
# 63.8815
# 63.9712
# 64.1851
# 63.8705
# 64.7177
# 64.9981
# 69.822
# 71.7688
# 72.6079
# 70.3536
# 68.5749
# 66.953
# 63.7478
# 64.1109
# 63.7479
# 63.661
# 63.642
# 62.4259
# 63.4891
# 63.8448
# 63.5586
# 63.4064
# 62.7807
# 62.1379
# 63.4732
# 64.0658
# 64.8035
# 65.3587
# 65.4057
# 64.889
# 64.5831
# 63.9081
# 64.3354
# 64.8293
# 65.0391
# 65.3918
# 65.363
# 65.5846
# 65.4012
# 64.5786
# 64.3469
# 64.8837
# 64.9954
# 66.0511
# 67.4562
# 68.4407
# 68.7964
# 68.6357
# 68.362
# 67.2584
# 66.208
# 64.7061
# 64.2149
# 64.6024
# 65.3792
# 64.951
# 64.7271
# 63.9843
# 63.6561
# 62.7933
# 63.0406
# 61.8995
# 62.604
# 63.3892
# 63.938
# 63.6113
# 62.5257
# 62.985
# 63.2368
# 63.3868
# 63.3942
# 64.6924
# 65.7951
# 66.6961
# 65.5609
# 64.2041
# 63.8739
# 64.1011
# 63.1908
# 62.8128
# 62.1443
# 62.0205
# 62.4479
# 62.4528
# 62.8323
# 63.8511
# 64.766
# 65.2738
# 65.3963
# 63.5507
# 62.683
# 61.8012
# 61.3866
# 62.132
# 64.0482
# 63.8494
# 63.5966
# 61.5057
# 61.3881
# 61.1905
# 61.9395
# 61.8267
# 60.3939
# 58.4422
# 54.0854
# 52.0133
# 51.4653
# 51.7469
# 54.1695
# 54.2803
# 54.1894
# 52.7785
# 52.1046
# 51.6882
# 51.7073
# 52.0769
# 53.4693
# 53.3563
# 52.6659
# 52.3408
# 51.6487
# 51.0078
# 51.392
# 51.526
# 51.9193
# 51.7038
# 51.7648
# 52.7154
# 55.9316
# 54.998
# 56.2202
# 55.4033
# 54.6874
# 54.4964
# 52.4921
# 52.1052
# 51.9457
# 51.9612
# 40.8515
# 56.9944
# 57.3109
# 57.3789
# 58.3398
# 56.8272
# 57.792
# 58.4358
# 59.9025
# 79.4426
# 61.1385
# 58.6323
# 58.0079
# 58.503
# 59.7952
# 60.7731
# 60.2072
# 60.5916
# 60.1494
# 60.0347
# 51.1404
# 60.2356
# 60.186
# 60.1205
# 61.4489
# 64.3051
# 64.1494
# 64.0803
# 63.6893
# 62.5495
# 62.1158
# 62.1123
# 62.3728
# 63.3789
# 64.878
# 66.5404
# 67.0663
# 67.1216
# 66.0856
# 65.8995
# 64.9174
# 62.5814
# 62.4218
# 50.7427
# 50.7434
# 50.7321
# 50.7263
# 50.8476
# 50.8551
# 50.8168
# 50.779
# 50.8272
# 50.88
# 50.8839
# 50.7712
# 50.8682
# 50.4952
# 50.5142
# 50.4151
# 49.641
# 50.2433
# 57.691
# 57.3703
# 63.323
# 63.6385
# 56.4438
# 55.7855
# 52.7105
# 57.1942
# 61.587
# 63.9402
# 65.5513
# 65.9433
# 63.8517
# 60.9961
# 57.3133
# 56.205
# 50.974
# 50.4729
# 50.8531
# 49.9111
# 50.0342
# 49.381
# 53.6851
# 57.599
# 64.8557
# 69.9431
# 74.1444
# 76.3219
# 74.5964
# 74.3299
# 70.2081
# 65.9004
# 58.1879
# 52.1673
# 49.4556
# 51.303
# 54.5859
# 61.1857
# 69.5519
# 78.1357
# 76.9407
# 74.8205
# 72.0872
# 64.2209
# 66.1184
# 66.7581
# 78.26
# 73.4691
# 61.3863
# 65.3743
# 61.4887
# 66.6197
# 70.4828
# 67.7231
# 64.3481
# 65.1631
# 65.4461
# 62.548
# 63.523
# 65.3325
# 64.6018
# 64.151
# 62.9086
# 60.6571
# 56.31
# 55.2225
# 55.3892
# 56.953
# 59.8975
# 60.7301
# 60.7993
# 62.28
# 63.0834
# 62.7123
# 62.538
# 61.3388
# 57.304
# 54.0441
# 52.3514
# 50.3507
# 50.3188
# 50.4241
# 49.0461
# 50.1731
# 55.8868
# 59.1047
# 62.2152
# 65.3116
# 63.2889
# 63.4192
# 63.0345
# 60.1081
# 56.7524
# 54.5297
# 50.6369
# 50.4873
# 53.8845
# 51.9472
# 51.6748
# 51.6211
# 62.8486
# 65.647
# 64.505
# 59.351
# 55.2951
# 46.1935
# 47.3543
# 48.2299
# 48.7259
# 48.8395
# 49.3272
# 49.4728
# 49.428
# 48.8582
# 49.4944
# 49.8564
# 52.0388
# 56.6264
# 60.8564
# 65.3856
# 66.5932
# 62.3651
# 58.2701
# 53.6217
# 53.026
# 53.8335
# 54.008
# 54.3245
# 52.8828
# 51.373
# 50.3314
# 49.8114
# 49.9478
# 50.7623
# 51.9854
# 53.716
# 56.7901
# 57.7685
# 58.547
# 59.7548
# 61.2169
# 61.3572
# 63.6866
# 62.1903
# 62.7534
# 63.1594
# 63.3152
# 63.0416
# 62.3681
# 61.4992
# 61.8479
# 61.4267
# 61.7262
# 61.6629
# 61.6286
# 62.1365
# 53.8721
# 63.1365
# 62.5773
# 65.5269
# 65.3867
# 65.4606
# 63.9018
# 58.3001
# 55.1492
# 52.0506
# 52.9916
# 55.1167
# 60.8125
# 62.156
# 61.3476
# 56.2039
# 53.854
# 52.3665
# 52.3339
# 55.5293
# 60.1679
# 61.1982
# 63.1099
# 63.2789
# 63.1922
# 62.9694
# 62.8786
# 62.6561
# 59.2453
# 54.3223
# 54.681
# 56.8215
# 59.3014
# 63.1288
# 63.4366
# 62.0291
# 60.6526
# 60.4188
# 59.7605
# 52.2934
# 50.4759
# 50.4601
# 50.2726
# 50.4287
# 50.4865
# 50.953
# 63.5042
# 64.1236
# 64.0708
# 64.039
# 64.0733
# 63.7265
# 61.9732
# 59.7913
# 58.1688
# 57.3717
# 58.3869
# 59.8776
# 60.5475
# 60.7065
# 60.6377
# 61.0271
# 61.2763
# 62.1906
# 62.8024
# 63.9338
# 64.7036
# 65.5474
# 65.2586
# 65.7445
# 66.6269
# 65.8016
# 65.5072
# 64.5648
# 63.277
# 63.25
# 63.7807
# 64.9587
# 66.3315
# 66.7797
# 66.9313
# 65.6333
# 64.5994
# 64.0689
# 62.2
# 61.6138
# 61.88
# 62.0404
# 63.3719
# 63.9824
# 63.7409
# 63.7687
# 63.4878
# 64.9219
# 65.3233
# 66.7124
# 67.3808
# 67.3165
# 67.7992
# 68.3011
# 67.7818
# 67.5836
# 66.7818
# 65.946
# 65.4325
# 65.1067
# 64.9569
# 65.2818
# 65.1149
# 65.7295
# 64.7235
# 63.5864
# 62.5327
# 62.0043
# 61.7872
# 61.7213
# 62.0223
# 61.5133
# 59.96
# 59.9314
# 58.3704
# 55.9866
# 53.5862
# 51.566
# 49.7383
# 49.2934
# 49.1004
# 49.6748
# 50.7671
# 50.9168
# 50.755
# 50.75
# 50.6956
# 50.5047
# 50.1304
# 54.6045
# 52.954
# 54.419
# 54.7692
# 53.9961
# 50.7609
# 50.4569
# 51.6577
# 54.0869
# 55.2483
# 59.3723
# 61.643
# 63.4253
# 65.4441
# 65.5859
# 63.1956
# 57.3177
# 54.0101
# 53.8638
# 51.2167
# 50.66
# 50.7671
# 50.9979
# 50.8544
# 49.3833
# 48.1873
# 47.7714
# 47.8232
# 48.0681
# 49.0093
# 49.5284
# 49.1574
# 50.2218
# 50.1305
# 50.1842
# 50.5327
# 50.4754
# 50.5591
# 51.1533
# 51.1501
# 50.9498
# 51.0106
# 50.8729
# 50.818
# 50.6026
# 50.2624
# 51.2397
# 51.2359
# 51.1545
# 50.2492
# 50.3373
# 49.7466
# 49.8679
# 50.0745
# 49.3108
# 48.7554
# 50.4231
# 50.3124
# 51.3266
# 51.2
# 50.1629
# 49.8458
# 49.0466
# 48.033
# 46.3559
# 46.9048
# 48.5469
# 48.563
# 49.1511
# 49.3224
# 48.4805
# 48.9088
# 49.1504
# 50.3265
# 52.3857
# 55.8531
# 59.5936
# 61.4476
# 59.1348
# 58.2695
# 57.6309
# 57.38
# 59.0088
# 60.105
# 60.5121
# 60.3631
# 60.0492
# 59.9797
# 60.9059
# 60.3102
# 60.0212
# 59.4014
# 57.515
# 56.6877
# 55.6245
# 54.618
# 53.8652
# 53.4825
# 51.3099
# 50.0303
# 51.98
# 52.3512
# 54.5946
# 56.8747
# 57.5691
# 57.6735
# 58.1712
# 58.6541
# 58.5301
# 58.0508
# 57.3543
# 55.362
# 54.8457
# 55.6403
# 57.4115
# 58.4362
# 57.9454
# 57.4074
# 57.747
# 58.7405
# 58.9988
# 59.9296
# 60.8975
# 61.6303
# 61.9982
# 61.8434
# 64.8708
# 63.4467
# 64.4755
# 63.8598
# 63.5494
# 61.6538
# 60.5208
# 59.3055
# 59.451
# 58.8869
# 58.0751
# 56.0956
# 55.4082
# 54.6019
# 55.9028
# 55.1887
# 55.3
# 53.581
# 50.6195
# 48.5491
# 47.4775
# 46.9972
# 47.9953
# 48.3702
# 49.2967
# 48.5749
# 49.4058
# 48.7437
# 48.7428
# 48.9184
# 48.9243
# 49.6356
# 49.9476
# 50.2365
# 51.8661
# 52.2823
# 52.6442
# 52.4755
# 50.5901
# 51.4737
# 56.4279
# 56.317
# 56.0192
# 56.2427
# 56.1967
# 59.2749
# 59.3796
# 59.3496
# 59.4763
# 59.5193
# 60.1633
# 60.2489
# 60.4662
# 59.8045
# 59.7169
# 59.3136
# 58.8713
# 60.728
# 61.5171
# 61.7392
# 62.0138
# 61.7374
# 61.516
# 61.3138
# 61.3056
# 61.1192
# 61.427
# 60.1201
# 60.5366
# 61.1715
# 60.5855
# 60.4035
# 60.4725
# 59.0353
# 59.4317
# 59.3398
# 61.4525
# 63.1056
# 61.9813
# 62.2713
# 62.1433
# 61.7432
# 63.5674
# 64.2437
# 65.0928
# 65.4178
# 64.784
# 64.3051
# 62.7448
# 61.2815
# 61.0602
# 61.3492
# 62.5743
# 64.3008
# 65.1843
# 66.4186
# 65.8741
# 65.4912
# 66.3875
# 67.4639
# 68.8659
# 70.0652
# 68.6182
# 69.5791
# 71.3672
# 72.5892
# 76.1896
# 87.9497
# 101.5666
# 98.7453
# 94.9142
# 80.549
# 69.0137
# 65.5806
# 60.3584
# 58.8294
# 63.5663
# 65.9908
# 66.4395
# 66.59
# 66.3942
# 65.5842
# 64.4415
# 64.4299
# 63.516
# 63.8625
# 63.3699
# 62.5235
# 62.5609
# 61.8501
# 60.62
# 58.935
# 57.6825
# 56.9877
# 56.5389
# 57.4029
# 57.5652
# 56.1027
# 55.1351
# 54.2364
# 53.2154
# 52.5638
# 52.8819
# 52.2052
# 52.0064
# 51.9496
# 51.2921
# 52.9085
# 52.9084
# 52.9209
# 54.2744
# 54.2135
# 54.6661
# 54.0831
# 54.4702
# 54.5458
# 55.1314
# 56.6005
# 56.6493
# 56.059
# 54.6858
# 53.7574
# 54.3532
# 54.8281
# 55.444
# 55.4101
# 55.2655
# 55.4067
# 56.4014
# 56.6362
# 56.4036
# 57.0294
# 57.6547
# 56.3645
# 54.8266
# 53.0878
# 51.0037
# 50.8233
# 52.1955
# 53.4039
# 55.822
# 56.5128
# 57.6666
# 58.2024
# 59.2118
# 63.8056
# 66.906
# 67.543
# 69.352
# 67.3753
# 67.8962
# 68.5703
# 67.9616
# 69.678
# 73.1492
# 79.8074
# 70.8301
# 67.672
# 68.0799
# 66.0817
# 68.0671
# 68.9007
# 69.7584
# 67.8818
# 66.1761
# 65.5286
# 65.4918
# 65.1132
# 65.0694
# 65.4632
# 65.3469
# 66.9284
# 66.3625
# 66.2644
# 64.0809
# 63.1639
# 62.66
# 62.7621
# 63.3127
# 63.0254
# 63.3278
# 62.327
# 62.9858
# 62.0555
# 62.1717
# 62.3766
# 62.8009
# 62.2524
# 61.2691
# 61.1955
# 61.4062
# 61.609
# 60.8747
# 61.4137
# 61.7207
# 61.3572
# 61.1968
# 60.3431
# 59.5122
# 58.6065
# 57.3688
# 57.8044
# 56.6714
# 55.3132
# 53.526
# 51.3014
# 48.318
# 47.3179
# 46.9462
# 46.7254
# 47.777
# 47.2339
# 47.8614
# 48.1401
# 47.7105
# 49.2722
# 49.808
# 52.5237
# 55.3356
# 53.9961
# 54.9805
# 54.1924
# 53.6802
# 54.2557
# 51.0857
# 49.7246
# 49.2537
# 49.456
# 50.9804
# 49.0071
# 49.5118
# 49.397
# 49.5519
# 49.9715
# 49.3388
# 49.5065
# 49.9309
# 50.8317
# 52.1381
# 54.1425
# 57.53
# 60.5303
# 65.9226
# 70.862
# 75.6587
# 77.732
# 78.173
# 79.368
# 81.2141
# 83.6067
# 82.4291
# 81.432
# 79.6045
# 77.6831
# 76.2998
# 75.4667
# 75.4111
# 76.3843
# 76.0528
# 74.8188
# 74.3695
# 73.3296
# 72.7704
# 71.4877
# 70.7866
# 70.6645
# 70.7726
# 69.7247
# 69.442
# 69.2693
# 70.2667
# 72.1642
# 72.9587
# 72.8914
# 73.9375
# 74.5308
# 75.6192
# 74.6655
# 74.299
# 73.7179
# 72.3575
# 72.1223
# 71.4886
# 71.4162
# 71.5997
# 70.4633
# 68.7896
# 68.1842
# 67.9037
# 67.726
# 68.4321
# 69.0978
# 69.6832
# 70.7217
# 70.6953
# 70.8631
# 70.6914
# 70.8241
# 71.0963
# 71.1655
# 71.3641
# 71.7154
# 71.5601
# 71.5698
# 71.2449
# 71.1364
# 70.702
# 70.3872
# 70.7674
# 70.5035
# 71.0233
# 49.8998
# 70.7705
# 70.9586
# 72.1717
# 71.6551
# 71.9259
# 72.7205
# 72.3104
# 73.3762
# 74.2741
# 74.1826
# 74.2173
# 74.4061
# 72.6603
# 71.5321
# 88.3192
# 87.7491
# 87.8922
# 72.5139
# 71.9565
# 70.9008
# 71.3665
# 70.7153
# 71.3596
# 71.893
# 90.7264
# 89.6164
# 71.4672
# 71.0278
# 72.356
# 68.5266
# 68.5538
# 65.8273
# 68.1759
# 83.7998
# 84.3858
# 83.5927
# 65.2297
# 64.1801
# 60.9175
# 56.9362
# 56.223
# 55.4323
# 56.084
# 65.3025
# 60.59
# 61.5189
# 62.2471
# 61.3049
# 60.6887
# 55.2829
# 82.6555
# 84.828
# 84.6487
# 82.5254
# 62.26
# 60.2213
# 61.0562
# 60.0143
# 63.0804
# 63.213
# 61.2793
# 60.1996
# 59.302
# 60.8122
# 61.0363
# 61.3551
# 63.0671
# 63.8616
# 63.6914
# 64.0289
# 65.1712
# 64.8443
# 65.0399
# 65.5056
# 64.3521
# 63.3989
# 63.1912
# 62.2597
# 57.7982
# 55.2959
# 53.694
# 52.1745
# 56.0601
# 57.1495
# 61.5684
# 60.8898
# 61.759
# 63.6227
# 62.092
# 61.7272
# 63.9835
# 66.3234
# 58.7194
# 59.3913
# 61.4947
# 61.8442
# 63.5442
# 65.4568
# 65.0876
# 64.167
# 62.491
# 62.5131
# 62.8375
# 62.7507
# 63.6704
# 63.1559
# 62.9652
# 62.4502
# 61.8612
# 59.487
# 56.4314
# 53.1531
# 49.9816
# 48.3156
# 47.8291
# 48.1103
# 47.9655
# 48.3985
# 49.6035
# 50.1605
# 51.3345
# 51.7027
# 51.8989
# 51.89
# 51.702
# 51.827
# 51.3817
# 51.4528
# 52.6776
# 55.0703
# 57.7908
# 58.6991
# 61.5609
# 63.2611
# 63.0792
# 62.8139
# 63.4578
# 63.437
# 64.0378
# 64.4052
# 62.4507
# 61.57
# 58.4194
# 59.2866
# 57.926
# 57.1052
# 55.3014
# 54.2519
# 52.8758
# 50.5453
# 50.4655
# 50.3776
# 50.8066
# 51.4791
# 51.5488
# 51.6535
# 51.466
# 51.4428
# 51.6915
# 50.8287
# 50.2349
# 50.1062
# 51.456
# 54.8952
# 55.0285
# 54.9513
# 52.7917
# 52.6327
# 52.3051
# 51.6439
# 51.6769
# 51.5701
# 51.1447
# 51.2832
# 51.5784
# 51.734
# 51.996
# 52.3129
# 52.5665
# 54.9779
# 58.9418
# 60.5253
# 61.6428
# 61.4888
# 61.3451
# 62.9387
# 65.1719
# 66.7422
# 67.4922
# 67.2401
# 66.7235
# 65.9348
# 66.3044
# 67.5222
# 70.8257
# 71.9423
# 71.6073
# 70.6124
# 70.4776
# 70.4068
# 69.5782
# 68.5203
# 66.9689
# 65.5288
# 65.3241
# 64.9835
# 65.5006
# 65.8471
# 85.2323
# 85.3063
# 67.9747
# 67.9118
# 86.291
# 86.0571
# 88.1438
# 71.4312
# 69.927
# 69.9582
# 105.6181
# 110.4149
# 107.2226
# 94.0239
# 138.5386
# 115.5259
# 114.8346
# 113.876
# 108.0999
# 105.8549
# 97.1423
# 94.023
# 63.6898
# 64.1733
# 65.0155
# 64.7989
# 64.6355
# 65.8347
# 64.5947
# 64.3183
# 63.5856
# 63.2521
# 63.2413
# 62.2647
# 61.5902
# 61.5605
# 61.9332
# 62.3882
# 63.148
# 63.5334
# 63.2425
# 62.8378
# 61.3269
# 61.1946
# 60.9618
# 61.9891
# 62.3668
# 62.3684
# 62.4836
# 63.0159
# 63.1572
# 63.1538
# 62.6091
# 59.1196
# 56.7578
# 55.7535
# 56.0922
# 56.2149
# 58.6253
# 59.504
# 59.5972
# 59.4821
# 58.925
# 59.3071
# 58.1647
# 57.4261
# 58.4286
# 63.6604
# 65.1754
# 65.1774
# 66.1869
# 66.18
# 66.4277
# 65.9156
# 62.7158
# 62.0339
# 60.8734
# 56.8907
# 55.315
# 56.3775
# 58.0125
# 58.1902
# 59.1781
# 58.0953
# 58.1162
# 58.522
# 59.3901
# 58.9632
# 58.8222
# 60.6822
# 62.008
# 63.0312
# 64.341
# 62.7135
# 62.6267
# 61.3869
# 60.8224
# 60.8307
# 60.7762
# 57.7065
# 57.8036
# 57.7121
# 55.9331
# 55.6748
# 56.7615
# 59.4328
# 61.7191
# 64.7102
# 67.3085
# 68.387
# 68.7538
# 66.8704
# 65.8915
# 63.3948
# 61.2493
# 59.7143
# 59.4282
# 57.0589
# 54.6282
# 53.4106
# 51.2198
# 50.7856
# 49.9166
# 50.2869
# 50.8174
# 51.2218
# 52.2791
# 55.4585
# 55.4552
# 55.5254
# 55.7547
# 56.3263
# 57.3264
# 58.3861
# 57.4499
# 56.2429
# 54.7386
# 51.979
# 51.1894
# 48.2956
# 47.7862
# 47.8077
# 47.5468
# 47.7636
# 47.6778
# 47.6612
# 47.7764
# 47.7987
# 47.8053
# 47.8657
# 47.7301
# 47.7655
# 47.8083
# 47.7778
# 47.7827
# 47.8091
# 47.769
# 47.7607
# 47.7783
# 47.7763
# 47.7786
# 47.7807
# 47.7834
# 47.7778
# 47.7704
# 47.7752
# 47.7731
# 47.7722
# 47.7787
# 47.7742
# 47.7785
# 47.774
# 47.7736
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771
# 47.7771

# %%
log_list = []
log_depth = []
for i in range(len(log_curve_values)-1):
    log_list.append(log_curve_values[i])
    log_depth.append(873.0984 + i*log_curve[0].DepthInc().Value(SeisWare.Unit.Meter))

# %%
# %matplotlib inline

matplotlib.pyplot.plot(log_list,log_depth)
matplotlib.pyplot.gca().invert_yaxis()

# %%
log_curve[0].Name()
# Out:
# 'DT'

# %%
log_curve[0].TopDepth().Value(SeisWare.Unit.Meter)
# Out:
# 1308.0492

# %% [markdown]
# Once we have the values in our DoublesList, we filter out any
# values that are not between our two well tops. We then filter our list once again to remove any null
# values, so they don't mess with out min/max/avg calculations.

# %% [markdown]
# We calculate the min, max, and avg by using the built-in Python function min, max, sum, and len, which return the minimum value of a list, return the maximum value of a list, return the sum of all the values of a list, and return the size of the list respectively.

# %%
log_curve_values_between_tops = [log_curve_value for i, log_curve_value in enumerate(log_curve_values) if top_well_top.MD() <= (log_curve[0].TopDepth() + (log_curve[0].DepthInc() * i)) <= base_well_top.MD()]
log_curve_values_between_tops_no_nulls = [log_curve_value for log_curve_value in log_curve_values_between_tops if log_curve_value != log_curve[0].NullValue()]
log_curve_minimum_value = min(log_curve_values_between_tops_no_nulls)
log_curve_maximum_value = max(log_curve_values_between_tops_no_nulls)
log_curve_average_value = sum(log_curve_values_between_tops_no_nulls) / len(log_curve_values_between_tops_no_nulls)

# %% [markdown]
# We calculate the min, max, and avg by using the built-in Python function min, max, sum, and len, which return the minimum value of a list, return the maximum value of a list, return the sum of all the values of a list, and return the size of the list respectively.

# %%
print("Number of values in log curve %s: %i" % (log_curve[0].Name(), len(log_curve_values)))
print("Number of values between well top %s and well top %s: %i" % (top_well_top.Formation(), base_well_top.Formation(), len(log_curve_values_between_tops)))
print("Minimum value between well top %s and well top %s: %.4f" % (top_well_top.Formation(), base_well_top.Formation(), log_curve_minimum_value))
print("Maximum value between well top %s and well top %s: %.4f" % (top_well_top.Formation(), base_well_top.Formation(), log_curve_maximum_value))
print("Average of values between well top %s and well top %s: %.4f" % (top_well_top.Formation(), base_well_top.Formation(), log_curve_average_value))
print()
# Out:
# Number of values in log curve DT: 2954
# Number of values between well top Top 2 and well top Top 1: 206
# Minimum value between well top Top 2 and well top Top 1: 40.5624
# Maximum value between well top Top 2 and well top Top 1: 123.7224
# Average of values between well top Top 2 and well top Top 1: 72.2349

# %%
def log_curve_type_to_string(log_curve_type):
    """
    Helper function to turn the log curve type into a string so we can print it.
    """
    if log_curve_type == SeisWare.LogCurveType_Sonic:
        return "Sonic"
    elif log_curve_type == SeisWare.LogCurveType_Density:
        return "Density"
    elif log_curve_type == SeisWare.LogCurveType_GammaRay:
        return "Gamma Ray"
    elif log_curve_type == SeisWare.LogCurveType_Depth:
        return "Depth"
    elif log_curve_type == SeisWare.LogCurveType_Synthetic:
        return "Synthetic"
    else:
        return "Unknown"

# %% [markdown]
# Write Log Curve to CSV
#
# We first create a file for writing, where if the file exists it will overwrite it and if it doesn't exist it will create it.

# %%
# Write the log curve header information
csv_file = open("%s.csv" % (log_curve[0].Name()), "w")

# %% [markdown]
# We then write a header which has details about the log curve, such as a name, description, units, and other information.

# %%
csv_file.write("Log Name: %s\n" % (log_curve[0].Name()))
csv_file.write("Description: %s\n" % (log_curve[0].Description()))
csv_file.write("Type: %s\n" % (log_curve_type_to_string(log_curve[0].Type())))
csv_file.write("Curve UOM: %s\n" % (log_curve[0].CurveUom()))
csv_file.write("Depth UOM: Meters\n")
csv_file.write("Source: %s\n" % (log_curve[0].Source()))
csv_file.write("Null Value: %.4f\n" % (log_curve[0].NullValue()))
csv_file.write("Top Depth: %.4f\n" % (log_curve[0].TopDepth().Value(SeisWare.Unit.Meter)))
csv_file.write("Base Depth: %.4f\n" % (log_curve[0].BaseDepth().Value(SeisWare.Unit.Meter)))
csv_file.write("Depth Increment: %.4f\n" % (log_curve[0].DepthInc().Value(SeisWare.Unit.Meter)))
csv_file.write("Depth,Value\n")
# Out:
# 12

# %% [markdown]
# Next we get the values out of the log curve by creating a SeisWare.DoublesList object and calling Values on our LogCurve object, passing in the DoublesList. We then print out the depth/value pairs, calculating the depth based on the log curves top depth and depth increment.

# %%
 # Write the depth/value pairs
for idx, val in enumerate(log_curve_values):
    csv_file.write("%.4f,%.4f\n" % ((log_curve[0].TopDepth() + (log_curve[0].DepthInc() * idx)).Value(SeisWare.Unit.Meter), val))

# %% [markdown]
# Finally we close the file to ensure everything gets saved.

# %%
# Close the file
csv_file.close()

# %% [markdown]
# # Getting the project grids
#
# We first get all the grids from the project by calling GetAll on the GridManager, which we get through our LoginInstance object. We then go through the GridList, looking for the grid with our passed in name.  It is also important to note that if you try to get the objects values before you call PopulateValues, it will throw.

# %%
    # Get the grids from the project
grid_list = SeisWare.GridList()

try:
        login_instance.GridManager().GetAll(grid_list)
except RuntimeError as err:
        handle_error("Failed to get the grids from the project", err)

for grid in grid_list:
        print(grid.Name())

   
    # Populate the grid with it's values
# Out:
# Top 1 Grid

# %%
grid_name = 'Top 1 Grid'

# Get the grid we want
grids = [grid for grid in grid_list if grid.Name() == grid_name]
if not grids:
    print("No grids were found", file=sys.stderr)
    sys.exit(1)

# %% [markdown]
# # Populate the grid with it's values

# %% [markdown]
# When we find it, we populate it a return it. The reason you have to call PopulateValues instead of just getting the values when you call GetAll is because the values are stored in a file and could take longer to get.

# %%
try:
    login_instance.GridManager().PopulateValues(grids[0])
except RuntimeError as err:
    handle_error("Failed to populate the values of grid %s from the project" % (grid_name), err)

# %% [markdown]
# # Return the grid

# %%
grid = grids[0]
# %matplotlib inline

# %% [markdown]
# We first get the values out of the grid by creating a SeisWare.GridValues object. We then call Values on our Grid object with the GridValues.  Finally we plot the grid as a triangle surface using matplotlib, setting a coolwarm color map and making the initial view be a top down one.

# %%
# Get the values from the grid
grid_values = SeisWare.GridValues()
# Populate grid_value with values
grid.Values(grid_values)

# %% [markdown]
# Next we create our axes such that the x-axis has values from 0 to grid cell width, the y-axis has values from 0 to grid cell height, and the z-axis has the grid values.

# %%
# Create the axes to plot the grid
x_axis = list(range(grid_values.Width())) * grid_values.Height()
y_axis = [y for y in range(grid_values.Height()) for _ in range(grid_values.Width())]
z_axis = grid_values.Data()

# %% [markdown]
# Finally we plot the grid.

# %%
# plot the grid
plot_figure = matplotlib.pyplot.figure()
plot_figure.canvas.set_window_title(grid.Name())
plot_axes = mpl_toolkits.mplot3d.Axes3D(plot_figure)
plot_axes.plot_trisurf(x_axis, y_axis, z_axis, cmap=matplotlib.pyplot.cm.coolwarm)
plot_axes.view_init(elev=90, azim=-90.0)
matplotlib.pyplot.savefig('Grid.pdf')
matplotlib.pyplot.show()
# Out:
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The set_window_title function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use `.FigureManagerBase.set_window_title` or GUI-specific methods instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Access Seismic Surveys

# %%
 # Get the seismic surveys from the project
seismic_list = SeisWare.SeismicSurveyList()

try:
        login_instance.SeismicSurveyManager().GetAll(seismic_list)
except RuntimeError as err:
        handle_error("Failed to get the seismic from the project", err)

for volume in seismic_list:
        print(volume.Name())
# Out:
# 3D
# Line-1
# Line-2

# %% [markdown]
# # Access Seismic Volume File Locations and Bulk Shifts

# %%
# Get the file location and bulk shift of "3D" for all the volumes.
seismic_volume_list = SeisWare.SeismicVolumeList()

try:
        login_instance.SeismicVolumeManager().GetAllForSeismicSurvey(seismic[0].ID(), seismic_volume_list)
except RuntimeError as err:
        handle_error("Failed to get seismic list from the project", err)

for volume in seismic_volume_list:
        seismic_bulkshift = login_instance.SeismicVolumeManager().GetBulkShift(volume.ID())
        if seismic_bulkshift.Domain() == SeisWare.UnitDomain_Time:
                units = "ms"        
        else:
                units = "meters"
        print(volume.FilePath())
        print(volume.Type())
        print(volume.Description())
        print(str(seismic_bulkshift.ToSI()) + units)
# Out:
# Failed to get seismic list from the project
# Error: Invalid argument: No database key matched.For seismic line - 1d328d74-797f-4701-ab18-044dbf37de53
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\apadilla\AppData\Local\Temp\ipykernel_23516\2532461483.py", line 5, in <module>
#     login_instance.SeismicVolumeManager().GetAllForSeismicSurvey(seismic[0].ID(), seismic_volume_list)
#   File "C:\Program Files\SeisWare SDK\10.7 Stable\py37\SeisWare\__init__.py", line 7434, in GetAllForSeismicSurvey
#     return _seisware_sdk_37.SeismicVolumeManager_GetAllForSeismicSurvey(self, seismicSurveyKey, seimicVolumeList)
# RuntimeError: Invalid argument: No database key matched.For seismic line - 1d328d74-797f-4701-ab18-044dbf37de53
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\apadilla\AppData\Local\Temp\ipykernel_23516\2532461483.py", line 7, in <module>
#     handle_error("Failed to get seismic list from the project", err)
#   File "C:\Users\apadilla\AppData\Local\Temp\ipykernel_23516\703375140.py", line 12, in handle_error
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\Users\apadilla\Anaconda3\envs\Py37\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23516\2532461483.py in <module>
#       4 try:
# ----> 5         login_instance.SeismicVolumeManager().GetAllForSeismicSurvey(seismic[0].ID(), seismic_volume_list)
#       6 except RuntimeError as err:
#
# C:\Program Files\SeisWare SDK\10.7 Stable\py37\SeisWare\__init__.py in GetAllForSeismicSurvey(self, seismicSurveyKey, seimicVolumeList)
#    7433     def GetAllForSeismicSurvey(self, seismicSurveyKey, seimicVolumeList):
# -> 7434         return _seisware_sdk_37.SeismicVolumeManager_GetAllForSeismicSurvey(self, seismicSurveyKey, seimicVolumeList)
#    7435
#
# RuntimeError: Invalid argument: No database key matched.For seismic line - 1d328d74-797f-4701-ab18-044dbf37de53
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_23516\2532461483.py in <module>
#       6 except RuntimeError as err:
# ----> 7         handle_error("Failed to get seismic list from the project", err)
#       8
#
# ~\AppData\Local\Temp\ipykernel_23516\703375140.py in handle_error(message, error)
#      11     print("Error: %s" % (error), file=sys.stderr)
# ---> 12     sys.exit(1)
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2069                            'the full traceback.\n']
#    2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2071                                                                      value))
#    2072                 else:
#    2073                     try:
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# c:\Users\apadilla\Anaconda3\envs\Py37\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
